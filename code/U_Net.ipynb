# %%
#!pip install --user numpy tqdm torchvision pandas seaborn matplotlib

# %%
import seaborn as sns

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
from torchvision import transforms, utils, datasets
from tqdm import tqdm ## This could help run time
 
#assert torch.cuda.is_available() # You need to request a GPU from Runtime > Change Runtime Type

# %%
#os.getcwd()
import os
os.listdir("../../compute/dili-broad")
# Out:
# ['BRD-K09635314-001-01-8',
#  'BRD-K48970916-001-03-0',
#  'BRD-A50311610-300-04-7',
#  'BRD-K66874953-001-02-7',
#  'BRD-K67511046-003-03-7',
#  'BRD-A32164164-048-01-4',
#  'BRD-A09533288-001-02-7',
#  'BRD-A57382968-001-06-8',
#  'BRD-K75958195-001-01-7',
#  'BRD-A05186015-003-04-0',
#  'BRD-K01815685-001-02-3',
#  'BRD-K25394294-001-04-0',
#  'BRD-K57718010-001-06-9',
#  'BRD-K18910433-001-04-4',
#  'BRD-K51276371-001-01-8',
#  'BRD-A18202423-001-01-6',
#  'BRD-A21723284-066-01-7',
#  'BRD-K42098891-003-03-1',
#  'BRD-A99411506-002-01-3',
#  'BRD-K71499074-001-03-8',
#  'BRD-K90259198-003-04-8',
#  'BRD-K63938928-001-02-5',
#  'BRD-A64125466-236-02-0',
#  'BRD-K77987382-001-05-8',
#  'BRD-A43930669-003-01-0',
#  'BRD-A22380646-001-01-5',
#  'BRD-K08287586-001-03-6',
#  'BRD-K62206109-303-01-1',
#  'BRD-K35586044-001-02-6',
#  'BRD-A50684349-001-01-5',
#  'BRD-K43290182-001-01-9',
#  'BRD-K15933101-003-01-2',
#  'BRD-K67013324-001-01-5',
#  'BRD-A36151937-001-01-2',
# ...

# %%
import os

#os.path.join("../../compute/dili-broad", "BRD-A00100033-001-04-8", "24294-A01-1", "mito.png")

#datasets.ImageFolder(os.path.join("../../compute/dili-broad", "BRD-A00100033-001-04-8", "24294-A01-1"))
#datatset_obj = datasets.ImageFolder(os.path.join("../../compute/dili-broad", "BRD-A00100033-001-04-8"))
datatset_obj = datasets.ImageFolder(os.path.join("../../compute/data"))

# %%
import IPython.display

#display(datatset_obj[239][0])
#len(datatset_obj)

datatset_obj[25000]
# Out:
# (<PIL.Image.Image image mode=RGB size=696x520 at 0x7F2BEAD556D8>, 2)
