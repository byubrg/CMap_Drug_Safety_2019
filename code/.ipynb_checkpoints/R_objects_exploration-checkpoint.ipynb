# %%
load("../data/r_objects/CAMDA_l1000_1314compounds-dilirank.rda")
load("../data/r_objects/CAMDA_l1000_1314compounds-GSE92742_Level5_gct.rda")
load("../data/r_objects/CAMDA_l1000_1314compounds-info.rda")
load("../data/r_objects/CAMDA_l1000_1314compounds-pert_iname.rda")

# %%
drank.sel
# Out:
#      LTKBID  PubChem_CID Compound.Name     ApprovalYear DILIConcern
# 9    LT02213 2081        alaproclate       .            Most-DILI-Concern
# 63   LT01042 6437841     acitretin         1996         Most-DILI-Concern
# 64   LT00046 2157        amiodarone        1985         Most-DILI-Concern
# 68   LT00539 28417       danazol           1976         Most-DILI-Concern
# 69   LT00080 2952        dantrolene        1974         Most-DILI-Concern
# 71   LT00097 3331        felbamate         1993         Most-DILI-Concern
# 75   LT02204 208908      lapatinib         2007         Most-DILI-Concern
# 76   LT00113 3899        leflunomide       1998         Most-DILI-Concern
# 78   LT01553 4178        mexiletine        1985         Most-DILI-Concern
# 83   LT00672 10113978    pazopanib         2009         Most-DILI-Concern
# 87   LT00565 5329102     sunitinib         2006         Most-DILI-Concern
# 98   LT01034 441184      acarbose          1995         Most-DILI-Concern
# ...

# %%
selDrugs
# Out:
#    [1] "rutin"
#    [2] "alaproclate"
#    [3] "albendazole"
#    [4] "alclometasone"
#    [5] "alfuzosin"
#    [6] "aliskiren"
#    [7] "altrenogest"
#    [8] "amcinonide"
#    [9] "AMG-9810"
#   [10] "spiramide"
#   [11] "aminoglutethimide"
#   [12] "aminopentamide"
#   [13] "amiodarone"
#   [14] "amlodipine"
#   [15] "amoxapine"
#   [16] "amsacrine"
#   [17] "anagrelide"
#   [18] "phenazone"
#   [19] "apigenin"
#   [20] "asiatic-acid"
#   [21] "azaperone"
#   [22] "ambroxol"
#   [23] "amperozide"
#   [24] "arcyriaflavin-a"
#   [25] "FTase-inhibitor-B581"
#   [26] "BADGE"
#   [27] "benzthiazide"
#   [28] "betamethasone"
#   [29] "betamethasone-acetate"
#   [30] "BH3I-1"
#   [31] "BIBX-1382"
#   [32] "biperiden"
#   [33] "bisacodyl"
#   [34] "bisoprolol"
#   [35] "bithionol"
#   [36] "bromocriptine"
#   [37] "brompheniramine"
#   [38] "bupropion"
#   [39] "butyl-paraben"
#   [40] "BW-B70C"
#   [41] "benazepril"
#   [42] "benzamil"
#   [43] "benzopurpurin-4b"
#   [44] "bucladesine"
# ...

# %%
selDrugsInfo13
# Out:
#       pert_iname              inchi_key
# 99    nifurtimox              ARFHIAQFJWUCFH-UHFFFAOYSA-N
# 101   hemado                  KOCIMZNSNPOGOP-UHFFFAOYSA-N
# 105   biperiden               YSXKPIUOCJLQIE-UHFFFAOYSA-N
# 107   noretynodrel            ICTXHFFSOAJUMG-OQPPHWFISA-N
# 113   7-hydroxy-PIPAT         RTMIJLQPWFKAFE-FPYGCLRLSA-N
# 114   7,8-dihydro-L-biopterin FEMXZDUTFRTWPE-YRAGUDHZSA-N
# 115   salmeterol              GIIZNNXWQWCKIB-UHFFFAOYSA-N
# 116   flumetasone             WXURHACBFYSXBI-DRBBXQFKSA-N
# 117   chlormadinone-acetate   QMBJSIBWORFWQT-GDMUWPLKSA-N
# 119   prednisolone-acetate    LRJOMUJRLNCICJ-AUGMLKDDSA-N
# 125   nitrendipine            PVHUJELLJLJGLN-UHFFFAOYSA-N
# 126   tubaic-acid             CMXGHLJKXLIMAQ-UHFFFAOYSA-N
# 127   betamethasone           UREBDLICKHMUKA-REKGUKDCSA-N
# 129   EMF-sumo1-9             BFQJGJYTDOYXDQ-UHFFFAOYSA-N
# 131   cyclopamine             QASFUMOKHFSJGL-ACLNMQFHSA-N
# ...

# %%
typeof(gct)

# gct@mat
# gct@rid
# gct@cid
# gct@rdesc
# gct@cdesc
# gct@src
# gct@version
# Out:
# [1] "S4"

# %%
# The original file I created I forgot to include the row.names.
write.csv(as.data.frame(t(gct@mat)), "../data/gct/transposed_mat.csv", row.names = TRUE)
